# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv('dataset/movie.csv')
ratings = pd.read_csv('dataset/rating.csv')[0:1000]
ratings.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
len(movies)
len(ratings)
# Out:
# 1000

# %%
ratings.drop(['timestamp'], axis=1, inplace=True)

# %%
ratings.head()
# Out:
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5
# 2       1       32     3.5
# 3       1       47     3.5
# 4       1       50     3.5

# %%
def replace_name(x):
    return movies[movies['movieId'] == x].title.values[0]

ratings.movieId = ratings.movieId.map(replace_name)
ratings.head()
# Out:
#    userId                                            movieId  rating
# 0       1                                     Jumanji (1995)     3.5
# 1       1  City of Lost Children, The (Cité des enfants p...     3.5
# 2       1          Twelve Monkeys (a.k.a. 12 Monkeys) (1995)     3.5
# 3       1                        Seven (a.k.a. Se7en) (1995)     3.5
# 4       1                         Usual Suspects, The (1995)     3.5

# %%
M = ratings.pivot_table(index=['userId'], columns=['movieId'], values='rating')

# %%
M
# Out:
# movieId  1984 (Nineteen Eighty-Four) (1984)  2001: A Space Odyssey (1968)  \
# userId
# 1                                       NaN                           3.5
# 2                                       NaN                           5.0
# 3                                       5.0                           5.0
# 4                                       NaN                           NaN
# 5                                       NaN                           NaN
# 6                                       NaN                           NaN
# 7                                       NaN                           3.0
# 8                                       NaN                           NaN
# 9                                       NaN                           NaN
# 10                                      NaN                           NaN
# 11                                      NaN                           NaN
#
# movieId  2010: The Year We Make Contact (1984)  28 Days (2000)  \
# ...

# %%
def pearson(s1, s2):
    s1_c = s1 - s1.mean()
    s2_c = s2 - s2.mean()
    
    a = np.sum(s1_c * s2_c)
    b = np.sqrt( np.sum(s1_c ** 2) * np.sum(s2_c ** 2) )
    
    if b > 0:
        return a/b
    
    return 0.0

# %%
pearson(M['1984 (Nineteen Eighty-Four) (1984)'], M['1984 (Nineteen Eighty-Four) (1984)'])
# Out:
# 0.0

# %%
def get_rec(movie_name, M, num):
    import numpy as np
    
    reviews = []
    
    for title in M.columns:
        if title == movie_name:
            continue
        cor = pearson(M[movie_name], M[title])
        if np.isnan(cor):
            continue
        else:
            reviews.append((title, cor))
            
    reviews.sort(key=lambda tup: tup[1], reverse=True)
    return reviews[:num]

# %%
recs = get_rec()
